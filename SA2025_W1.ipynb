# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
cars_data = pd.read_csv('/content/Cars.csv')
cars_data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
cars_data.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#print(cars_data.columns)
columns_array = cars_data.columns.values
print(columns_array)
# Out:
# ['mpg' 'cylinders' 'displacement' 'horsepower' 'weight' 'acceleration'
#  'model_year' 'origin' 'name']

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
cars_data.set_index('name', inplace=True)
cars_data.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin
# name
# chevrolet chevelle malibu          12.0          70    usa
# buick skylark 320                  11.5          70    usa
# plymouth satellite                 11.0          70    usa
# amc rebel sst                      12.0          70    usa
# ford torino                        10.5          70    usa

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
unique_mpg = cars_data['mpg'].unique()
print(unique_mpg)
# Out:
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
cars_data['hp_to_weight'] = cars_data['horsepower'] / cars_data['weight']
cars_data.set_index('hp_to_weight', inplace=True)
cars_data.head()
# Out:
#                mpg  cylinders  displacement  horsepower  weight  acceleration  \
# hp_to_weight
# 0.037100      18.0          8         307.0       130.0    3504          12.0
# 0.044679      15.0          8         350.0       165.0    3693          11.5
# 0.043655      18.0          8         318.0       150.0    3436          11.0
# 0.043694      16.0          8         304.0       150.0    3433          12.0
# 0.040591      17.0          8         302.0       140.0    3449          10.5
#
#               model_year origin
# hp_to_weight
# 0.037100              70    usa
# 0.044679              70    usa
# 0.043655              70    usa
# 0.043694              70    usa
# 0.040591              70    usa

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
cars_data = pd.read_csv('/content/Cars.csv')
car_with_max_hp = cars_data.loc[cars_data['horsepower'].idxmax(), 'name']
print("Car with the highest horsepower:", car_with_max_hp)
# Out:
# Car with the highest horsepower: pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
high_mpg_cars = cars_data[cars_data['mpg'] >= 35]
count = len(high_mpg_cars)
print(f"Number of cars with mpg ≥ 35: {count}")
# Out:
# Number of cars with mpg ≥ 35: 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
filtered_cars = cars_data[(cars_data['horsepower'] > 100) & (cars_data['weight'] < 3000)]
most_common_origin = filtered_cars['origin'].mode()[0]
print("Most common origin for cars with horsepower > 100 and weight < 3000:", most_common_origin)
# Out:
# Most common origin for cars with horsepower > 100 and weight < 3000: usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
for origin in cars_data['origin'].unique():
    origin_cars = cars_data[cars_data['origin'] == origin]
    mean_accel = round(origin_cars['acceleration'].mean(), 2)
    print(f"Mean acceleration for {origin}: {mean_accel}")
# Out:
# Mean acceleration for usa: 15.03
# Mean acceleration for japan: 16.17
# Mean acceleration for europe: 16.79

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
avg_mpg_by_year = cars_data.groupby('model_year')['mpg'].mean()
best_year = avg_mpg_by_year.idxmax()
highest_avg_mpg = round(avg_mpg_by_year.max(), 2)
print(f"Year with highest average MPG: {best_year} (Avg MPG: {highest_avg_mpg})")
# Out:
# Year with highest average MPG: 80 (Avg MPG: 33.7)

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
median_mpg = cars_data['mpg'].median()
cars_data['hp_to_weight'] = cars_data['horsepower'] / cars_data['weight']
high_mpg_cars = cars_data[cars_data['mpg'] > median_mpg]
best_ratio = high_mpg_cars['hp_to_weight'].max()
best_cars = high_mpg_cars[high_mpg_cars['hp_to_weight'] == best_ratio]
print(f"Best horsepower-to-weight ratio among high-MPG cars: {best_ratio:.4f}")
print("\nCars with this ratio:")
print(best_cars[['name', 'mpg', 'horsepower', 'weight', 'hp_to_weight']])
# Out:
# Best horsepower-to-weight ratio among high-MPG cars: 0.0506
#
# Cars with this ratio:
#         name   mpg  horsepower  weight  hp_to_weight
# 23  bmw 2002  26.0       113.0    2234      0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
import matplotlib.pyplot as plt
import seaborn as sns

avg_mpg = cars_data.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(
    data=avg_mpg,
    x='model_year',
    y='mpg',
    hue='origin',
    marker='o',
    linewidth=2.5
)

plt.title('Evolution of Average MPG by Origin (1970-1982)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average MPG', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
palette = {"japan": "#2ca02c", "europe": "#ff7f0e", "usa": "#1f77b4"}

plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(
    data=cars_data,
    x="horsepower",
    y="weight",
    hue="origin",
    size="mpg",
    hue_order=["japan", "europe", "usa"],
    palette=palette,
    alpha=0.8,
    sizes=(20, 200),
    edgecolor="black",
    linewidth=0.5
)

plt.title("Car Weight vs. Horsepower (Colored by Origin, Sized by MPG)", fontsize=14, pad=20)
plt.xlabel("Horsepower", fontsize=12)
plt.ylabel("Weight (lbs)", fontsize=12)
plt.legend(
    title="Origin",
    bbox_to_anchor=(1.05, 1),
    loc="upper left",
    frameon=True,
    framealpha=1
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
import pandas as pd

car_counts = cars_data['name'].value_counts()
multi_year_cars = car_counts[car_counts > 1].index.tolist()
multi_year_data = cars_data[cars_data['name'].isin(multi_year_cars)]
consistency_stats = (multi_year_data.groupby('name')['mpg']
                     .agg(['count', 'std', 'mean'])
                     .reset_index()
                     .rename(columns={'count': 'appearances',
                                     'std': 'mpg_std',
                                     'mean': 'avg_mpg'}))
consistent_cars = consistency_stats[
    (consistency_stats['mpg_std'] < 1.0) &
    (consistency_stats['appearances'] >= 2)
]
consistent_cars_sorted = consistent_cars.sort_values(
    by=['appearances', 'avg_mpg'],
    ascending=[False, False]
)
print("Most consistent car models (lowest MPG variation):")
print(consistent_cars_sorted[['name', 'appearances', 'avg_mpg', 'mpg_std']].to_string(index=False))
# Out:
# Most consistent car models (lowest MPG variation):
#                      name  appearances   avg_mpg  mpg_std
#          ford galaxie 500            3 14.333333 0.577350
#         plymouth fury iii            3 14.333333 0.577350
#       toyota corolla 1200            2 31.500000 0.707107
#                 mazda 626            2 31.450000 0.212132
#         volkswagen rabbit            2 29.250000 0.353553
#              datsun pl510            2 27.000000 0.000000
#                 saab 99le            2 24.500000 0.707107
#            toyota mark ii            2 19.500000 0.707107
#               dodge aspen            2 18.850000 0.353553
# chevrolet chevelle malibu            2 17.500000 0.707107
#          amc matador (sw)            2 14.500000 0.707107
#     ford gran torino (sw)            2 13.500000 0.707107
#                  ford ltd            2 13.500000 0.707107

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
